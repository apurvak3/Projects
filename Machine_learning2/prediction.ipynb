# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# %%
heart_rate = pd.read_csv("data.csv")
heart_rate.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
heart_rate.shape
# Out:
# (270, 14)

# %%
heart_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
heart_rate.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
heart_rate.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
heart_rate['Sex'].value_counts()
# Out:
# Sex
# 1    183
# 0     87
# Name: count, dtype: int64

# %%
X = heart_rate.drop(columns='Sex', axis = 1)
Y = heart_rate['Sex']

# %%
print(X)
print(Y)
# Out:
#      Age  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70                4  130          322             0            2
# 1     67                3  115          564             0            2
# 2     57                2  124          261             0            0
# 3     64                4  128          263             0            0
# 4     74                2  120          269             0            2
# ..   ...              ...  ...          ...           ...          ...
# 265   52                3  172          199             1            0
# 266   44                2  120          263             0            0
# 267   56                2  140          294             0            2
# 268   57                4  140          192             0            0
# 269   67                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder

# Then the rest of your code
categorical_cols = X_train.select_dtypes(include=['object']).columns
encoder = OneHotEncoder(sparse_output=False)
encoded_features = encoder.fit_transform(X_train[categorical_cols])
encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_cols))
# Combine with numeric features
numeric_cols = X_train.select_dtypes(exclude=['object']).columns
X_train_processed = pd.concat([X_train[numeric_cols].reset_index(drop=True), encoded_df.reset_index(drop=True)], axis=1)
# Now try fitting the model
model.fit(X_train_processed, Y_train)
# Out:
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20412\248686314.py in ?()
# ----> 1 model.fit(X_train , Y_train)
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1219             _dtype = np.float64
#    1220         else:
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
#    1224             X,
#    1225             y,
#    1226             accept_sparse="csr",
# ...

# %%
model.fit(X_train , Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20412\248686314.py in ?()
# ----> 1 model.fit(X_train , Y_train)
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1219             _dtype = np.float64
#    1220         else:
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
#    1224             X,
#    1225             y,
#    1226             accept_sparse="csr",
# ...

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print('Accuracy on training data:', training_data_accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20412\2798080738.py in ?()
# ----> 1 X_train_prediction = model.predict(X_train)
#       2 training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
#       3 print('Accuracy on training data:', training_data_accuracy)
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
#     378         y_pred : ndarray of shape (n_samples,)
#     379             Vector containing the class labels for each sample.
#     380         """
#     381         xp, _ = get_namespace(X)
# --> 382         scores = self.decision_function(X)
#     383         if len(scores.shape) == 1:
#     384             indices = xp.astype(scores > 0, indexing_dtype(xp))
#     385         else:
#
# c:\Users\kanth\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
# ...
